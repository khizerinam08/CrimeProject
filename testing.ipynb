# %% [markdown]
# 1.0,0.0,-0.901,0.4339,-87.66719,41.70931

# %%
import numpy as np
import joblib

# Fix: Properly formatted dictionary
data = {
    "lat": 41.76931,
    "lon": -87.66719,
    "hour": 12,
    "weekday": 0
}

model = joblib.load("crime_model.pkl")

sin_hour = np.sin(2 * np.pi * data['hour'] / 24)
cos_hour = np.cos(2 * np.pi * data['hour'] / 24)
sin_weekday = np.sin(2 * np.pi * data['weekday'] / 7)
cos_weekday = np.cos(2 * np.pi * data['weekday'] / 7)

test_point = [[data['lat'], data['lon'], sin_hour, cos_hour, sin_weekday, cos_weekday]]
prediction = model.predict_proba(test_point)
crime_prob = prediction[:, 1][0] * 100

print(f"Crime probability: {crime_prob:.2f}%")
# Out:
# Crime probability: 0.00%
# c:\Users\Administrator\Documents\Repos\CrimeProject\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
